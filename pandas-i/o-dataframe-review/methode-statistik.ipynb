# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaazza/mini-bootcamp-data-analyst-python/blob/main/pandas-i/o-dataframe-review/methode-statistik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Methode Statistik

# %%
import pandas as pd

pd.options.display.precision = 4

path = "/content/drive/MyDrive/Sertifikasi Data Analyst UDEMY/Sample Data/Pokemon.csv"
df = pd.read_csv(path, index_col='Num')
df.sample(4)
# Out:
#         Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Num
# 110  Weezing   Poison     NaN    490   65      90      120       85       70
# 151      Mew  Psychic     NaN    600  100     100      100      100      100
# 16    Pidgey   Normal  Flying    251   40      45       40       35       35
# 13    Weedle      Bug  Poison    195   40      35       30       20       20
#
#      Speed  Stage  Legendary
# Num
# 110     60      2      False
# 151    100      1      False
# 16      56      1      False
# 13      50      1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %% [markdown]
# Methode Describe
#
# memberikan ringkasan statistik deskriptif dari keseluruhan dataframe

# %%
df.describe()
# Out:
#           Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# count  151.0000  151.0000  151.0000  151.0000  151.0000  151.0000  151.0000
# mean   407.0795   64.2119   72.5497   68.2252   67.1391   66.0199   68.9338
# std     99.7438   28.5901   26.5962   26.9167   28.5342   24.1979   26.7469
# min    195.0000   10.0000    5.0000    5.0000   15.0000   20.0000   15.0000
# 25%    320.0000   45.0000   51.0000   50.0000   45.0000   49.0000   46.5000
# 50%    405.0000   60.0000   70.0000   65.0000   65.0000   65.0000   70.0000
# 75%    490.0000   80.0000   90.0000   84.0000   87.5000   80.0000   90.0000
# max    680.0000  250.0000  134.0000  180.0000  154.0000  125.0000  140.0000
#
#           Stage
# count  151.0000
# mean     1.5828
# std      0.6768
# min      1.0000
# 25%      1.0000
# 50%      1.0000
# 75%      2.0000
# max      3.0000

# %%
df.describe().T #transpos dataframe
# Out:
#          count      mean      std    min    25%    50%    75%    max
# Total    151.0  407.0795  99.7438  195.0  320.0  405.0  490.0  680.0
# HP       151.0   64.2119  28.5901   10.0   45.0   60.0   80.0  250.0
# Attack   151.0   72.5497  26.5962    5.0   51.0   70.0   90.0  134.0
# Defense  151.0   68.2252  26.9167    5.0   50.0   65.0   84.0  180.0
# Sp. Atk  151.0   67.1391  28.5342   15.0   45.0   65.0   87.5  154.0
# Sp. Def  151.0   66.0199  24.1979   20.0   49.0   65.0   80.0  125.0
# Speed    151.0   68.9338  26.7469   15.0   46.5   70.0   90.0  140.0
# Stage    151.0    1.5828   0.6768    1.0    1.0    1.0    2.0    3.0

# %%
df.describe?

# %%
df.describe(include = ['object']).T
# Out:
#        count unique         top freq
# Name     151    150  Nidoran���    2
# Type 1   151     15       Water   28
# Type 2    67     11      Poison   19

# %% [markdown]
# # Fungsi Statistik secara spesifik

# %% [markdown]
# Semua Kolom/baris

# %%
# karna tidak semua nilai numeric di berikan numeric_only
df.mean(numeric_only = True)
# Out:
# Total        407.0795
# HP            64.2119
# Attack        72.5497
# Defense       68.2252
# Sp. Atk       67.1391
# Sp. Def       66.0199
# Speed         68.9338
# Stage          1.5828
# Legendary      0.0265
# dtype: float64

# %%
df.std(numeric_only = True)
# Out:
# Total        99.7438
# HP           28.5901
# Attack       26.5962
# Defense      26.9167
# Sp. Atk      28.5342
# Sp. Def      24.1979
# Speed        26.7469
# Stage         0.6768
# Legendary     0.1611
# dtype: float64

# %% [markdown]
# Kolom baris tertentu

# %%
df['Attack'].mean()
# Out:
# np.float64(72.54966887417218)

# %%
df['Attack'].mean() + 3
# Out:
# np.float64(75.54966887417218)
