# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaazza/mini-bootcamp-data-analyst-python/blob/main/pandas-i/o-dataframe-review/head-tail-sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Sertifikasi Data Analyst UDEMY/Sample Data/provinsi_indonesia.csv'
df = pd.read_csv(path)
df
# Out:
#                Provinsi        Ibu Kota  Jumlah Penduduk
# 0                  Aceh      Banda Aceh          5274871
# 1        Sumatera Utara           Medan         14799361
# 2        Sumatera Barat          Padang          5534472
# 3                  Riau       Pekanbaru          6575405
# 4        Kepulauan Riau  Tanjung Pinang          2064564
# 5                 Jambi           Jambi          3548228
# 6      Sumatera Selatan       Palembang          8438660
# 7              Bengkulu        Bengkulu          2006687
# 8               Lampung  Bandar Lampung          9007848
# 9       Bangka Belitung  Pangkal Pinang          1501072
# 10          DKI Jakarta         Jakarta         10562088
# 11           Jawa Barat         Bandung         49316712
# 12               Banten          Serang         13904744
# 13          Jawa Tengah        Semarang         37103545
# 14        DI Yogyakarta      Yogyakarta          3668719
# ...

# %% [markdown]
# # Method Head
#
# Digunakan untuk menampilkan baris pertama dari dataframe

# %%
df.head()
# Out:
#          Provinsi        Ibu Kota  Jumlah Penduduk
# 0            Aceh      Banda Aceh          5274871
# 1  Sumatera Utara           Medan         14799361
# 2  Sumatera Barat          Padang          5534472
# 3            Riau       Pekanbaru          6575405
# 4  Kepulauan Riau  Tanjung Pinang          2064564

# %%
df.head(2)
# Out:
#          Provinsi    Ibu Kota  Jumlah Penduduk
# 0            Aceh  Banda Aceh          5274871
# 1  Sumatera Utara       Medan         14799361

# %% [markdown]
# # Method Tail
#
# Digunakan untuk menampilkan baris terakhir pada dataframe

# %%
df.tail()
# Out:
#             Provinsi  Ibu Kota  Jumlah Penduduk
# 33  Papua Barat Daya    Sorong          1134068
# 34  Papua Pegunungan    Wamena          1561100
# 35      Papua Tengah    Nabire          1489000
# 36     Papua Selatan   Merauke          1468400
# 37             Papua  Jayapura          2852803

# %%
df.tail(4)
# Out:
#             Provinsi  Ibu Kota  Jumlah Penduduk
# 34  Papua Pegunungan    Wamena          1561100
# 35      Papua Tengah    Nabire          1489000
# 36     Papua Selatan   Merauke          1468400
# 37             Papua  Jayapura          2852803

# %% [markdown]
# # Method Sample
#
# Digunakan untuk menampilkan baris secaraacak dari DataFrame

# %%
df.sample()
# Out:
#    Provinsi  Ibu Kota  Jumlah Penduduk
# 7  Bengkulu  Bengkulu          2006687

# %%
df.sample(3)
# Out:
#             Provinsi       Ibu Kota  Jumlah Penduduk
# 32       Papua Barat      Manokwari          1134068
# 23  Kalimantan Utara  Tanjung Selor           701894
# 15        Jawa Timur       Surabaya         41149225

# %%
path = '/content/drive/MyDrive/Sertifikasi Data Analyst UDEMY/Sample Data/Pokemon.csv'
df = pd.read_csv(path, index_col='Num')
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Num
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# Num
# 1         65     45      1      False
# ...

# %%
df.head(5)
# Out:
#            Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Num
# 1     Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2       Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3      Venusaur  Grass  Poison    525  80      82       83      100      100
# 4    Charmander   Fire     NaN    309  39      52       43       60       50
# 5    Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#      Speed  Stage  Legendary
# Num
# 1       45      1      False
# 2       60      2      False
# 3       80      3      False
# 4       65      1      False
# 5       80      2      False

# %%
df.tail(5)
# Out:
#           Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Num
# 147    Dratini   Dragon     NaN    300   41      64       45       50
# 148  Dragonair   Dragon     NaN    420   61      84       65       70
# 149  Dragonite   Dragon  Flying    600   91     134       95      100
# 150     Mewtwo  Psychic     NaN    680  106     110       90      154
# 151        Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# Num
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False

# %%
df.sample(5)
# Out:
#         Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Num
# 18   Pidgeot    Normal  Flying    479   83      80       75       70       70
# 143  Snorlax    Normal     NaN    540  160     110       65       65      110
# 132    Ditto    Normal     NaN    288   48      48       48       48       48
# 26    Raichu  Electric     NaN    485   60      90       55       90       80
# 151      Mew   Psychic     NaN    600  100     100      100      100      100
#
#      Speed  Stage  Legendary
# Num
# 18     101      3      False
# 143     30      1      False
# 132     48      1      False
# 26     110      2      False
# 151    100      1      False
