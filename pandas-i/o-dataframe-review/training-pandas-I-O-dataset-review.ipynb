# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaazza/mini-bootcamp-data-analyst-python/blob/main/pandas-i/o-dataframe-review/training-pandas-I-O-dataset-review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Buatlah dataframe dengan nama digimon dari file digimon.csv yang tercantum di dalam resource video ini! Jadikan kolom Number sebagai indexnya.

# %%
path = '/content/drive/MyDrive/Sertifikasi Data Analyst UDEMY/Sample Data/digimon.csv'
df_digimon = pd.read_csv(path)
df_digimon
# Out:
#                   Digimon Stage     Type Attribute  Memory  Equip Slots  \
# Number
# 1                 Kuramon  Baby     Free   Neutral       2            0
# 2                 Pabumon  Baby     Free   Neutral       2            0
# 3                 Punimon  Baby     Free   Neutral       2            0
# 4                 Botamon  Baby     Free   Neutral       2            0
# 5                 Poyomon  Baby     Free   Neutral       2            0
# ...                   ...   ...      ...       ...     ...          ...
# 245            Valkyrimon  Mega     Free      Wind      18            3
# 246       ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 247     MirageGaogamon BM  Mega     Data     Light      20            2
# 248            Ravemon BM  Mega  Vaccine      Wind      20            2
# 249            Rosemon BM  Mega     Data     Plant      20            2
#
#         Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# Number
# ...

# %% [markdown]
# 2. Gunakan method head untuk menampilkan 5 baris pertama!

# %%
df_digimon.head(5)
# Out:
#         Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  Lv50 SP  \
# Number
# 1       Kuramon  Baby  Free   Neutral       2            0       590       77
# 2       Pabumon  Baby  Free   Neutral       2            0       950       62
# 3       Punimon  Baby  Free   Neutral       2            0       870       50
# 4       Botamon  Baby  Free   Neutral       2            0       690       68
# 5       Poyomon  Baby  Free   Neutral       2            0       540       98
#
#         Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# Number
# 1             79        69        68        95
# 2             76        76        69        68
# 3             97        87        50        75
# 4             77        95        76        61
# 5             54        59        95        86

# %% [markdown]
# 3. Gunakan method info untuk melihat informasi umum dari dataframe digimon!

# %%
df_digimon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 1 to 249
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Digimon      249 non-null    object
#  1   Stage        249 non-null    object
#  2   Type         249 non-null    object
#  3   Attribute    249 non-null    object
#  4   Memory       249 non-null    int64
#  5   Equip Slots  249 non-null    int64
#  6   Lv 50 HP     249 non-null    int64
#  7   Lv50 SP      249 non-null    int64
#  8   Lv50 Atk     249 non-null    int64
#  9   Lv50 Def     249 non-null    int64
#  10  Lv50 Int     249 non-null    int64
#  11  Lv50 Spd     249 non-null    int64
# dtypes: int64(8), object(4)
# memory usage: 25.3+ KB

# %% [markdown]
# 4. Dengan menggunakan method describe*, tampilkan hasil seperti berikut ini.

# %%
print(df_digimon.describe())
print("========================")
print(df_digimon.describe(include=['object']))
# Out:
#        Memory  Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# count  249.00       249.00    249.00   249.00    249.00    249.00    249.00    249.00
# mean    11.99         1.57   1210.88   109.78    124.52    116.38    112.64    120.40
# std      6.62         0.85    326.10    32.45     45.64     32.13     41.56     32.63
# min      2.00         0.00    530.00    50.00     52.00     59.00     50.00     61.00
# 25%      6.00         1.00    990.00    84.00     89.00     93.00     79.00     92.00
# 50%     12.00         1.00   1180.00   104.00    119.00    113.00    104.00    119.00
# 75%     18.00         2.00   1480.00   132.00    153.00    138.00    138.00    143.00
# max     25.00         3.00   2080.00   203.00    318.00    213.00    233.00    218.00
# ...
#         Digimon Stage   Type Attribute
# count       249   249    249       249
# unique      249     8      4         9
# top     Kuramon  Mega  Virus      Dark
# freq          1    74     82        37

# %% [markdown]
# 5. Atur agar tampilan baris pada method : digimon.describe() tidak terbagi-bagi (gunakan pandas.options.display)

# %%
pd.options.display.width = 1000
print(df_digimon.describe())
print("========================")
print(df_digimon.describe(include=['object']))
# Out:
#        Memory  Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# count  249.00       249.00    249.00   249.00    249.00    249.00    249.00    249.00
# mean    11.99         1.57   1210.88   109.78    124.52    116.38    112.64    120.40
# std      6.62         0.85    326.10    32.45     45.64     32.13     41.56     32.63
# min      2.00         0.00    530.00    50.00     52.00     59.00     50.00     61.00
# 25%      6.00         1.00    990.00    84.00     89.00     93.00     79.00     92.00
# 50%     12.00         1.00   1180.00   104.00    119.00    113.00    104.00    119.00
# 75%     18.00         2.00   1480.00   132.00    153.00    138.00    138.00    143.00
# max     25.00         3.00   2080.00   203.00    318.00    213.00    233.00    218.00
# ...
#         Digimon Stage   Type Attribute
# count       249   249    249       249
# unique      249     8      4         9
# top     Kuramon  Mega  Virus      Dark
# freq          1    74     82        37

# %% [markdown]
# 6. Atur agar tampilan bilangan desimal hanya terdiri dari 2 angka di belakang koma pada method : digimon.describe()seperti di soal no. 5

# %%
pd.options.display.width = 1000
pd.options.display.precision = 2
print(df_digimon.describe())
print("========================")
print(df_digimon.describe(include=['object']))
# Out:
#        Memory  Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# count  249.00       249.00    249.00   249.00    249.00    249.00    249.00    249.00
# mean    11.99         1.57   1210.88   109.78    124.52    116.38    112.64    120.40
# std      6.62         0.85    326.10    32.45     45.64     32.13     41.56     32.63
# min      2.00         0.00    530.00    50.00     52.00     59.00     50.00     61.00
# 25%      6.00         1.00    990.00    84.00     89.00     93.00     79.00     92.00
# 50%     12.00         1.00   1180.00   104.00    119.00    113.00    104.00    119.00
# 75%     18.00         2.00   1480.00   132.00    153.00    138.00    138.00    143.00
# max     25.00         3.00   2080.00   203.00    318.00    213.00    233.00    218.00
# ...
#         Digimon Stage   Type Attribute
# count       249   249    249       249
# unique      249     8      4         9
# top     Kuramon  Mega  Virus      Dark
# freq          1    74     82        37

# %% [markdown]
# 7. Digimon tipe apa yang paling banyak di dalam dataframe? dan berapa banyak frukensinya?

# %%
df_digimon.describe(include = ['object'])['Type']
# Out:
# count       249
# unique        4
# top       Virus
# freq         82
# Name: Type, dtype: object

# %% [markdown]
# 8. Berapa nilai varians dari kolom Lv 50 HP?

# %%
df_digimon['Lv 50 HP'].var()
# Out:
# 106342.76460681428

# %% [markdown]
# 9. Berapa nilai skewness (kemiringan) dari kolom Lv50 Atk?

# %%
df_digimon['Lv50 Atk'].skew()
# Out:
# np.float64(0.7155221183448726)

# %% [markdown]
# 10. Berapa nilai percentil 30 dari kolom Lv50 Atk?

# %%
df_digimon['Lv50 Atk'].quantile(0.30)
# Out:
# np.float64(94.0)
