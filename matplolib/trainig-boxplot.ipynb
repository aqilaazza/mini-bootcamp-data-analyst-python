# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaazza/mini-bootcamp-data-analyst-python/blob/main/matplolib/trainig-boxplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Sertifikasi Data Analyst UDEMY/Sample Data/diabetes_dataset00.csv')
df
# Out:
#                                         Target Genetic Markers Autoantibodies  \
# 0                     Steroid-Induced Diabetes        Positive       Negative
# 1             Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                                  Prediabetic        Positive       Positive
# 3                              Type 1 Diabetes        Negative       Positive
# 4                             Wolfram Syndrome        Negative       Negative
# ...                                        ...             ...            ...
# 69995                 Steroid-Induced Diabetes        Negative       Negative
# 69996                                     LADA        Positive       Positive
# 69997                          Type 1 Diabetes        Positive       Negative
# 69998  Cystic Fibrosis-Related Diabetes (CFRD)        Positive       Negative
# 69999                                     LADA        Positive       Positive
#
# ...

# %% [markdown]
# Buatlah boxplot dari Blood_Pressure berdasarkan jenis diabetesnya/prediabeticnya (Target)!

# %%
df['Target'].unique()
# Out:
# array(['Steroid-Induced Diabetes', 'Neonatal Diabetes Mellitus (NDM)',
#        'Prediabetic', 'Type 1 Diabetes', 'Wolfram Syndrome', 'LADA',
#        'Type 2 Diabetes', 'Wolcott-Rallison Syndrome',
#        'Secondary Diabetes', 'Type 3c Diabetes (Pancreatogenic Diabetes)',
#        'Gestational Diabetes', 'Cystic Fibrosis-Related Diabetes (CFRD)',
#        'MODY'], dtype=object)

# %%
jenis_diabetes = df['Target'].unique()
data_diabetes = []
target_param = 'BMI'

for jenis in jenis_diabetes:
    filter = df['Target'] == jenis
    data = df[filter][target_param]
    data_diabetes.append(data)

plt.figure(figsize=(8,6))

plt.boxplot(data_diabetes, vert=False)

plt.yticks([i for i in range(1, 14)], jenis_diabetes)
plt.title(f'Boxplot {target_param} \nBerdasarkan Jenis Diabetes/ Kondisi Prediabetes')
plt.ylabel('Jenis Diabetes/ Kondisi Prediabetes')
plt.xlabel(f'{target_param}')
plt.grid(axis='x')

plt.show()
