# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaazza/mini-bootcamp-data-analyst-python/blob/main/data-cleaning/training-data-cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path = '/content/drive/MyDrive/Sertifikasi Data Analyst UDEMY/Sample Data/data_unclean.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    ID  Age  Gender    Income Date of Joining          City  Happiness Score  \
# 0   1   30  Female   70000.0      2020-01-01    Balikpapan               70
# 1   2   25    male   30000.0      2020-01-02  Palangkaraya              150
# 2   3   45  Female  110000.0      2020-01-03  Palangkaraya               50
# 3   4   40    male   50000.0      2020-01-04       Tarakan               70
# 4   5   40    Male   70000.0      2020-01-05    balikpapan              100
#
#                    Email_POS Education
# 0   user32@example.com;77969       PhD
# 1   user84@example.com;48044    Master
# 2    user1@example.com;12695       PhD
# 3   user99@example.com;74820       PhD
# 4  user100@example.com;45920  Bachelor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               103 non-null    int64
#  1   Age              103 non-null    int64
#  2   Gender           103 non-null    object
#  3   Income           87 non-null     float64
#  4   Date of Joining  103 non-null    object
#  5   City             89 non-null     object
#  6   Happiness Score  103 non-null    int64
#  7   Email_POS        103 non-null    object
#  8   Education        103 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 7.4+ KB

# %% [markdown]
# Perbaiki data type

# %%
df['Date of Joining'] = pd.to_datetime(df['Date of Joining'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               103 non-null    int64
#  1   Age              103 non-null    int64
#  2   Gender           103 non-null    object
#  3   Income           87 non-null     float64
#  4   Date of Joining  103 non-null    datetime64[ns]
#  5   City             89 non-null     object
#  6   Happiness Score  103 non-null    int64
#  7   Email_POS        103 non-null    object
#  8   Education        103 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 7.4+ KB

# %% [markdown]
# Mengisi data null

# %%
df.isnull().sum()
# Out:
# ID                  0
# Age                 0
# Gender              0
# Income             16
# Date of Joining     0
# City               14
# Happiness Score     0
# Email_POS           0
# Education           0
# dtype: int64

# %%
df['Income'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 98     False
# 99     False
# 100    False
# 101    False
# 102     True
# Name: Income, Length: 103, dtype: bool

# %%
df[df['Income'].isnull()]
# Out:
#      ID  Age  Gender  Income Date of Joining          City  Happiness Score  \
# 5     6   35    male     NaN      2020-01-06  Palangkaraya              150
# 10   11   25  female     NaN      2020-01-11           NaN              150
# 20   21   25       M     NaN      2020-01-21     taranakan               50
# 26   27   40    male     NaN      2020-01-27  Palangkaraya               90
# 28   29   30  female     NaN      2020-01-29       Tarakan              150
# 29   30   30    Male     NaN      2020-01-30           NaN              100
# 30   31   60  female     NaN      2020-01-31     Samarinda               50
# 34   35   45       F     NaN      2020-02-04       Tarakan               90
# 53   54   50  female     NaN      2020-02-23     Samarinda              100
# 73   74   45    Male     NaN      2020-03-14    balikpapan              100
# 74   75   30  Female     NaN      2020-03-15           NaN              200
# ...

# %%
df['Income'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-41-3824672977.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                  0
# Age                 0
# Gender              0
# Income              0
# Date of Joining     0
# City               14
# Happiness Score     0
# Email_POS           0
# Education           0
# dtype: int64

# %%
df[df['City'].isnull()]
# Out:
#      ID  Age  Gender    Income Date of Joining City  Happiness Score  \
# 10   11   25  female       0.0      2020-01-11  NaN              150
# 27   28   50       M   30000.0      2020-01-28  NaN              100
# 29   30   30    Male       0.0      2020-01-30  NaN              100
# 39   40   30       M   50000.0      2020-02-09  NaN              100
# 41   42   50    Male   90000.0      2020-02-11  NaN               60
# 43   44   30       M   90000.0      2020-02-13  NaN               80
# 50   51   60    male  110000.0      2020-02-20  NaN              150
# 58   59   45       F   50000.0      2020-02-28  NaN              100
# 72   73   60  female   90000.0      2020-03-13  NaN              150
# 74   75   30  Female       0.0      2020-03-15  NaN              200
# 79   80   60    male   50000.0      2020-03-20  NaN               70
# 82   83   45       F   50000.0      2020-03-23  NaN              100
# 95   96   35  female  110000.0      2020-04-05  NaN              150
# ...

# %%
df['City'].fillna('Unknow', inplace=True)
# Out:
# /tmp/ipython-input-44-1492324962.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna('Unknow', inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                 0
# Age                0
# Gender             0
# Income             0
# Date of Joining    0
# City               0
# Happiness Score    0
# Email_POS          0
# Education          0
# dtype: int64

# %%
df.describe()
# Out:
#                ID         Age         Income                Date of Joining  \
# count  103.000000  103.000000     103.000000                            103
# mean    50.815534   42.766990   56019.417476  2020-02-19 19:34:22.135922432
# min      1.000000   25.000000  -10000.000000            2020-01-01 00:00:00
# 25%     26.500000   30.000000   30000.000000            2020-01-26 12:00:00
# 50%     51.000000   40.000000   50000.000000            2020-02-20 00:00:00
# 75%     75.500000   50.000000   90000.000000            2020-03-15 12:00:00
# max    100.000000   70.000000  110000.000000            2020-04-09 00:00:00
# std     28.899334   12.713436   37346.806195                            NaN
#
#        Happiness Score
# count       103.000000
# mean        101.747573
# min          50.000000
# 25%          70.000000
# 50%          90.000000
# 75%         150.000000
# max         200.000000
# std          43.822887

# %% [markdown]
# Membenahi data error

# %%
#filter kolom income
filter_income = df['Income'] < 0
df[filter_income]
# Out:
#     ID  Age  Gender   Income Date of Joining          City  Happiness Score  \
# 42  43   40  Female -10000.0      2020-02-12     Pontianak              150
# 45  46   40    Male -10000.0      2020-02-15  Palangkaraya               50
#
#                    Email_POS Education
# 42  user98@example.com;11016  Bachelor
# 45  user39@example.com;12695  Bachelor

# %%
index_income = df[filter_income].index
df.loc[index_income, 'Income'] = 0

# %%
filter_income = df['Income'] < 0
df[filter_income]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Income, Date of Joining, City, Happiness Score, Email_POS, Education]
# Index: []

# %%
#pisah kolom email dan pos
df['Email_POS']
# Out:
# 0       user32@example.com;77969
# 1       user84@example.com;48044
# 2        user1@example.com;12695
# 3       user99@example.com;74820
# 4      user100@example.com;45920
#                  ...
# 98      user89@example.com;92798
# 99      user32@example.com;74820
# 100     user96@example.com;58984
# 101     user69@example.com;64886
# 102     user28@example.com;54131
# Name: Email_POS, Length: 103, dtype: object

# %%
df['Email_POS'].str.split(';', expand=True)
# Out:
#                        0      1
# 0     user32@example.com  77969
# 1     user84@example.com  48044
# 2      user1@example.com  12695
# 3     user99@example.com  74820
# 4    user100@example.com  45920
# ..                   ...    ...
# 98    user89@example.com  92798
# 99    user32@example.com  74820
# 100   user96@example.com  58984
# 101   user69@example.com  64886
# 102   user28@example.com  54131
#
# [103 rows x 2 columns]

# %%
df[['Email', 'POS']] = df['Email_POS'].str.split(';', expand=True)
df
# Out:
#       ID  Age  Gender    Income Date of Joining          City  \
# 0      1   30  Female   70000.0      2020-01-01    Balikpapan
# 1      2   25    male   30000.0      2020-01-02  Palangkaraya
# 2      3   45  Female  110000.0      2020-01-03  Palangkaraya
# 3      4   40    male   50000.0      2020-01-04       Tarakan
# 4      5   40    Male   70000.0      2020-01-05    balikpapan
# ..   ...  ...     ...       ...             ...           ...
# 98    99   30       M  110000.0      2020-04-08       Tarakan
# 99   100   60       M   30000.0      2020-04-09    Balikpapan
# 100   90   40       F   70000.0      2020-03-30     Pontianak
# 101   59   45       F   50000.0      2020-02-28        Unknow
# 102   35   45       F       0.0      2020-02-04       Tarakan
#
#      Happiness Score                  Email_POS Education  \
# 0                 70   user32@example.com;77969       PhD
# 1                150   user84@example.com;48044    Master
# ...

# %%
df.drop(columns= 'Email_POS', inplace=True)
df
# Out:
#       ID  Age  Gender    Income Date of Joining          City  \
# 0      1   30  Female   70000.0      2020-01-01    Balikpapan
# 1      2   25    male   30000.0      2020-01-02  Palangkaraya
# 2      3   45  Female  110000.0      2020-01-03  Palangkaraya
# 3      4   40    male   50000.0      2020-01-04       Tarakan
# 4      5   40    Male   70000.0      2020-01-05    balikpapan
# ..   ...  ...     ...       ...             ...           ...
# 98    99   30       M  110000.0      2020-04-08       Tarakan
# 99   100   60       M   30000.0      2020-04-09    Balikpapan
# 100   90   40       F   70000.0      2020-03-30     Pontianak
# 101   59   45       F   50000.0      2020-02-28        Unknow
# 102   35   45       F       0.0      2020-02-04       Tarakan
#
#      Happiness Score Education                Email    POS
# 0                 70       PhD   user32@example.com  77969
# 1                150    Master   user84@example.com  48044
# ...
