# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaazza/mini-bootcamp-data-analyst-python/blob/main/seaborn/visualisasi-relasi-regresi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mengganti Style

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Menyiapkan Data
penguins = sns.load_dataset('penguins')
penguins.sample(5)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 255  Gentoo  Biscoe            48.4           16.3              220.0
# 275  Gentoo  Biscoe            45.0           15.4              220.0
# 294  Gentoo  Biscoe            46.4           15.0              216.0
# 36   Adelie   Dream            38.8           20.0              190.0
# 258  Gentoo  Biscoe            44.0           13.6              208.0
#
#      body_mass_g     sex
# 255       5400.0    Male
# 275       5050.0    Male
# 294       4700.0  Female
# 36        3950.0    Male
# 258       4350.0  Female

# %%
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=penguins, hue='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
# macam-macam style
styles = ['white', 'dark', 'whitegrid', 'darkgrid', 'ticks']

for style in styles:
    sns.set_style(style)
    sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=penguins, hue='sex')
    plt.title(f'Style {style}')
    plt.show()

# %%
sns.set_style('whitegrid')
sns.set_context('notebook')

contexts = ['paper', 'notebook', 'talk', 'poster']
for context in contexts:
    sns.set_context(context)
    sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=penguins, hue='sex')
    plt.title(f'Context {context}')
    plt.show()

# %% [markdown]
# #Plot Relasional

# %%
    sns.lineplot(x='flipper_length_mm', y='body_mass_g', data=penguins)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
    sns.regplot(x='flipper_length_mm', y='body_mass_g', data=penguins)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
    sns.lmplot(x='flipper_length_mm', y='body_mass_g', data=penguins, hue = 'species')

# %%
sns.residplot(x='flipper_length_mm', y='body_mass_g', data=penguins)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>
